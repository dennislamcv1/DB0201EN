# %% [markdown]
# The practice problems for this Lab will provide hands on experience with string patterns, sorting result sets and grouping result sets. You will also learn how to run SQL scripts to create several tables at once, as well as how to load data into tables from .csv files.

# %% [markdown]
# **HR Database**
#
# We will be working on a sample HR database for this Lab. This HR database schema consists of 5 tables called EMPLOYEES, JOB_HISTORY, JOBS, DEPARTMENTS and LOCATIONS. Each table has a few rows of sample data The following diagram shows the tables for the HR database.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline
sns.set_style('dark')
sns.set(font_scale=1.2)

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %% [markdown]
# ### Part I: CREATING TABLES

# %% [markdown]
# ### Part II: LOADING DATA

# %%
employees = pd.read_csv("Employees.csv",parse_dates=['B_DATE'],dayfirst=True)

# %%
employees
# Out:
#   EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 0  E1001     John   Thomas  123456 1976-09-01   M
# 1  E1002    Alice    James  123457 1972-07-31   F
# 2  E1003    Steve    Wells  123458 1980-10-08   M
# 3  E1004  Santosh    Kumar  123459 1985-07-20   M
# 4  E1005    Ahmed  Hussain  123410 1981-04-01   M
# 5  E1006    Nancy    Allen  123411 1978-06-02   F
# 6  E1007     Mary   Thomas  123412 1975-05-05   F
# 7  E1008  Bharath    Gupta  123413 1985-06-05   M
# 8  E1009   Andrea    Jones  123414 1990-09-07   F
# 9  E1010      Ann    Jacob  123415 1982-03-30   F
#
#                         ADDRESS  JOB_ID  SALARY  MANAGER_ID  DEP_ID
# 0         5631 Rice, OakPark,IL     100  100000       30001       2
# 1        980 Berry ln, Elgin,IL     200   80000       30002       5
# 2          291 Springs, Gary,IL     300   50000       30002       5
# 3      511 Aurora Av, Aurora,IL     400   60000       30004       5
# 4       216 Oak Tree, Geneva,IL     500   70000       30001       2
# 5        111 Green Pl, Elgin,IL     600   90000       30001       2
# 6          100 Rose Pl, Gary,IL     650   65000       30003       7
# 7   145 Berry Ln, Naperville,IL     660   65000       30003       7
# 8       120 Fall Creek, Gary,IL     234   70000       30003       7
# 9  111 Britany Springs,Elgin,IL     220   70000       30004       5

# %%
locations = pd.read_csv("Locations.csv")

# %%
locations
# Out:
#   LOCT_ID  DEP_ID_LOC
# 0   L0001           2
# 1   L0002           5
# 2   L0003           7

# %%
jobhistory = pd.read_csv("JobsHistory.csv")

# %%
jobhistory
# Out:
#   EMPL_ID  START_DATE  JOBS_ID  DEPT_ID
# 0   E1001    8/1/2000      100        2
# 1   E1002    8/1/2001      200        5
# 2   E1003  08/16/2001      300        5
# 3   E1004  08/16/2000      400        5
# 4   E1005  05/30/2000      500        2
# 5   E1006  08/16/2001      600        2
# 6   E1007  05/30/2002      650        7
# 7   E1008    5/6/2010      660        7
# 8   E1009  08/16/2016      234        7
# 9   E1010  08/16/2016      220        5

# %%
jobs = pd.read_csv("Jobs.csv")

# %%
jobs
# Out:
#    JOB_IDENT               JOB_TITLE  MIN_SALARY  MAX_SALARY
# 0        100           Sr. Architect       60000      100000
# 1        200  Sr. Software Developer       60000       80000
# 2        300   Jr.Software Developer       40000       60000
# 3        400   Jr.Software Developer       40000       60000
# 4        500           Jr. Architect       50000       70000
# 5        600          Lead Architect       70000      100000
# 6        650            Jr. Designer       60000       70000
# 7        660            Jr. Designer       60000       70000
# 8        234            Sr. Designer       70000       90000
# 9        220            Sr. Designer       70000       90000

# %%
dept = pd.read_csv("Departments.csv")

# %%
dept
# Out:
#    DEPT_ID         DEP_NAME  MANAGER_ID LOC_ID
# 0        2  Architect Group       30001  L0001
# 1        5   Software Group       30002  L0002
# 2        7      Design Team       30003  L0003
# 3        5   Software Group       30004  L0004

# %% [markdown]
# Question 1: Were there any warnings loading data into the JOBS table? What can be done to resolve this?

# %% [markdown]
# Question 2: Did all rows from the source file load successfully in the DEPARTMENT table? If not, are you able to figure out why not?

# %% [markdown]
# ### Part III: COMPOSING AND RUNNING QUERIES

# %% [markdown]
# Query 1: Retrieve all employees whose address is in Elgin,IL

# %%
employees
# Out:
#   EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 0  E1001     John   Thomas  123456 1976-09-01   M
# 1  E1002    Alice    James  123457 1972-07-31   F
# 2  E1003    Steve    Wells  123458 1980-10-08   M
# 3  E1004  Santosh    Kumar  123459 1985-07-20   M
# 4  E1005    Ahmed  Hussain  123410 1981-04-01   M
# 5  E1006    Nancy    Allen  123411 1978-06-02   F
# 6  E1007     Mary   Thomas  123412 1975-05-05   F
# 7  E1008  Bharath    Gupta  123413 1985-06-05   M
# 8  E1009   Andrea    Jones  123414 1990-09-07   F
# 9  E1010      Ann    Jacob  123415 1982-03-30   F
#
#                         ADDRESS  JOB_ID  SALARY  MANAGER_ID  DEP_ID
# 0         5631 Rice, OakPark,IL     100  100000       30001       2
# 1        980 Berry ln, Elgin,IL     200   80000       30002       5
# 2          291 Springs, Gary,IL     300   50000       30002       5
# 3      511 Aurora Av, Aurora,IL     400   60000       30004       5
# 4       216 Oak Tree, Geneva,IL     500   70000       30001       2
# 5        111 Green Pl, Elgin,IL     600   90000       30001       2
# 6          100 Rose Pl, Gary,IL     650   65000       30003       7
# 7   145 Berry Ln, Naperville,IL     660   65000       30003       7
# 8       120 Fall Creek, Gary,IL     234   70000       30003       7
# 9  111 Britany Springs,Elgin,IL     220   70000       30004       5

# %%
employees[employees['ADDRESS'].str.contains('Elgin,IL')]
# Out:
#   EMP_ID F_NAME L_NAME     SSN     B_DATE SEX                       ADDRESS  \
# 1  E1002  Alice  James  123457 1972-07-31   F        980 Berry ln, Elgin,IL
# 5  E1006  Nancy  Allen  123411 1978-06-02   F        111 Green Pl, Elgin,IL
# 9  E1010    Ann  Jacob  123415 1982-03-30   F  111 Britany Springs,Elgin,IL
#
#    JOB_ID  SALARY  MANAGER_ID  DEP_ID
# 1     200   80000       30002       5
# 5     600   90000       30001       2
# 9     220   70000       30004       5

# %% [markdown]
# Query 2: Retrieve all employees who were born during the 1970's.

# %%
employees['YEAROFBIRTH'] = employees['B_DATE'].dt.year

# %%
employees
# Out:
#   EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 0  E1001     John   Thomas  123456 1976-09-01   M
# 1  E1002    Alice    James  123457 1972-07-31   F
# 2  E1003    Steve    Wells  123458 1980-10-08   M
# 3  E1004  Santosh    Kumar  123459 1985-07-20   M
# 4  E1005    Ahmed  Hussain  123410 1981-04-01   M
# 5  E1006    Nancy    Allen  123411 1978-06-02   F
# 6  E1007     Mary   Thomas  123412 1975-05-05   F
# 7  E1008  Bharath    Gupta  123413 1985-06-05   M
# 8  E1009   Andrea    Jones  123414 1990-09-07   F
# 9  E1010      Ann    Jacob  123415 1982-03-30   F
#
#                         ADDRESS  JOB_ID  SALARY  MANAGER_ID  DEP_ID  \
# 0         5631 Rice, OakPark,IL     100  100000       30001       2
# 1        980 Berry ln, Elgin,IL     200   80000       30002       5
# 2          291 Springs, Gary,IL     300   50000       30002       5
# 3      511 Aurora Av, Aurora,IL     400   60000       30004       5
# 4       216 Oak Tree, Geneva,IL     500   70000       30001       2
# 5        111 Green Pl, Elgin,IL     600   90000       30001       2
# 6          100 Rose Pl, Gary,IL     650   65000       30003       7
# 7   145 Berry Ln, Naperville,IL     660   65000       30003       7
# 8       120 Fall Creek, Gary,IL     234   70000       30003       7
# 9  111 Britany Springs,Elgin,IL     220   70000       30004       5
#
#    YEAROFBIRTH
# 0         1976
# 1         1972
# 2         1980
# 3         1985
# 4         1981
# 5         1978
# 6         1975
# 7         1985
# 8         1990
# 9         1982

# %%
employees[employees['YEAROFBIRTH'] < 1980 ]
# Out:
#   EMP_ID F_NAME  L_NAME     SSN     B_DATE SEX                 ADDRESS  \
# 0  E1001   John  Thomas  123456 1976-09-01   M   5631 Rice, OakPark,IL
# 1  E1002  Alice   James  123457 1972-07-31   F  980 Berry ln, Elgin,IL
# 5  E1006  Nancy   Allen  123411 1978-06-02   F  111 Green Pl, Elgin,IL
# 6  E1007   Mary  Thomas  123412 1975-05-05   F    100 Rose Pl, Gary,IL
#
#    JOB_ID  SALARY  MANAGER_ID  DEP_ID  YEAROFBIRTH
# 0     100  100000       30001       2         1976
# 1     200   80000       30002       5         1972
# 5     600   90000       30001       2         1978
# 6     650   65000       30003       7         1975

# %% [markdown]
# Query 3: Retrieve all employees in department 5 whose salary is between 60000 and 70000.

# %%
dept5 = employees[employees['DEP_ID'] == 5]
dept5
# Out:
#   EMP_ID   F_NAME L_NAME     SSN     B_DATE SEX                       ADDRESS  \
# 1  E1002    Alice  James  123457 1972-07-31   F        980 Berry ln, Elgin,IL
# 2  E1003    Steve  Wells  123458 1980-10-08   M          291 Springs, Gary,IL
# 3  E1004  Santosh  Kumar  123459 1985-07-20   M      511 Aurora Av, Aurora,IL
# 9  E1010      Ann  Jacob  123415 1982-03-30   F  111 Britany Springs,Elgin,IL
#
#    JOB_ID  SALARY  MANAGER_ID  DEP_ID  YEAROFBIRTH
# 1     200   80000       30002       5         1972
# 2     300   50000       30002       5         1980
# 3     400   60000       30004       5         1985
# 9     220   70000       30004       5         1982

# %%
dept5[dept5['SALARY'].between(60000,70000,inclusive=True)]
# Out:
#   EMP_ID   F_NAME L_NAME     SSN     B_DATE SEX                       ADDRESS  \
# 3  E1004  Santosh  Kumar  123459 1985-07-20   M      511 Aurora Av, Aurora,IL
# 9  E1010      Ann  Jacob  123415 1982-03-30   F  111 Britany Springs,Elgin,IL
#
#    JOB_ID  SALARY  MANAGER_ID  DEP_ID  YEAROFBIRTH
# 3     400   60000       30004       5         1985
# 9     220   70000       30004       5         1982

# %% [markdown]
# Query 4A: Retrieve a list of employees ordered by department ID.

# %%
employees.sort_values(by='DEP_ID')
# Out:
#   EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 0  E1001     John   Thomas  123456 1976-09-01   M
# 4  E1005    Ahmed  Hussain  123410 1981-04-01   M
# 5  E1006    Nancy    Allen  123411 1978-06-02   F
# 1  E1002    Alice    James  123457 1972-07-31   F
# 2  E1003    Steve    Wells  123458 1980-10-08   M
# 3  E1004  Santosh    Kumar  123459 1985-07-20   M
# 9  E1010      Ann    Jacob  123415 1982-03-30   F
# 6  E1007     Mary   Thomas  123412 1975-05-05   F
# 7  E1008  Bharath    Gupta  123413 1985-06-05   M
# 8  E1009   Andrea    Jones  123414 1990-09-07   F
#
#                         ADDRESS  JOB_ID  SALARY  MANAGER_ID  DEP_ID  \
# 0         5631 Rice, OakPark,IL     100  100000       30001       2
# 4       216 Oak Tree, Geneva,IL     500   70000       30001       2
# 5        111 Green Pl, Elgin,IL     600   90000       30001       2
# 1        980 Berry ln, Elgin,IL     200   80000       30002       5
# 2          291 Springs, Gary,IL     300   50000       30002       5
# 3      511 Aurora Av, Aurora,IL     400   60000       30004       5
# 9  111 Britany Springs,Elgin,IL     220   70000       30004       5
# 6          100 Rose Pl, Gary,IL     650   65000       30003       7
# 7   145 Berry Ln, Naperville,IL     660   65000       30003       7
# 8       120 Fall Creek, Gary,IL     234   70000       30003       7
#
#    YEAROFBIRTH
# 0         1976
# 4         1981
# 5         1978
# 1         1972
# 2         1980
# 3         1985
# 9         1982
# 6         1975
# 7         1985
# 8         1990

# %% [markdown]
# Query 4B: Retrieve a list of employees ordered in descending order by department ID and within each department ordered alphabetically in descending order by last name.

# %%
employees.sort_values(by='DEP_ID',ascending=False)
# Out:
#   EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 6  E1007     Mary   Thomas  123412 1975-05-05   F
# 7  E1008  Bharath    Gupta  123413 1985-06-05   M
# 8  E1009   Andrea    Jones  123414 1990-09-07   F
# 1  E1002    Alice    James  123457 1972-07-31   F
# 2  E1003    Steve    Wells  123458 1980-10-08   M
# 3  E1004  Santosh    Kumar  123459 1985-07-20   M
# 9  E1010      Ann    Jacob  123415 1982-03-30   F
# 0  E1001     John   Thomas  123456 1976-09-01   M
# 4  E1005    Ahmed  Hussain  123410 1981-04-01   M
# 5  E1006    Nancy    Allen  123411 1978-06-02   F
#
#                         ADDRESS  JOB_ID  SALARY  MANAGER_ID  DEP_ID  \
# 6          100 Rose Pl, Gary,IL     650   65000       30003       7
# 7   145 Berry Ln, Naperville,IL     660   65000       30003       7
# 8       120 Fall Creek, Gary,IL     234   70000       30003       7
# 1        980 Berry ln, Elgin,IL     200   80000       30002       5
# 2          291 Springs, Gary,IL     300   50000       30002       5
# 3      511 Aurora Av, Aurora,IL     400   60000       30004       5
# 9  111 Britany Springs,Elgin,IL     220   70000       30004       5
# 0         5631 Rice, OakPark,IL     100  100000       30001       2
# 4       216 Oak Tree, Geneva,IL     500   70000       30001       2
# 5        111 Green Pl, Elgin,IL     600   90000       30001       2
#
#    YEAROFBIRTH
# 6         1975
# 7         1985
# 8         1990
# 1         1972
# 2         1980
# 3         1985
# 9         1982
# 0         1976
# 4         1981
# 5         1978

# %% [markdown]
# Query 5A: For each department ID retrieve the number of employees in the department.

# %%
employees.groupby('DEP_ID')['EMP_ID'].count()
# Out:
# DEP_ID
# 2    3
# 5    4
# 7    3
# Name: EMP_ID, dtype: int64

# %% [markdown]
# Query 5B: For each department retrieve the number of employees in the department, and the average employees salary in the department.

# %%
employees.groupby('DEP_ID')['SALARY'].mean()
# Out:
# DEP_ID
# 2    86666.666667
# 5    65000.000000
# 7    66666.666667
# Name: SALARY, dtype: float64

# %% [markdown]
# Query 5C: Label the computed columns in the result set of Query 5B as “NUM_EMPLOYEES” and “AVG_SALARY”.

# %%
df = employees.groupby('DEP_ID',as_index=False)['SALARY'].mean()

# %%
df
# Out:
#    DEP_ID        SALARY
# 0       2  86666.666667
# 1       5  65000.000000
# 2       7  66666.666667

# %%
df.columns = ['NUM_EMPLOYEES','AVG_SALARY']

# %%
df
# Out:
#    NUM_EMPLOYEES    AVG_SALARY
# 0              2  86666.666667
# 1              5  65000.000000
# 2              7  66666.666667

# %% [markdown]
# Query 5D: In Query 5C order the result set by Average Salary

# %%
df.sort_values(by='AVG_SALARY')
# Out:
#    NUM_EMPLOYEES    AVG_SALARY
# 1              5  65000.000000
# 2              7  66666.666667
# 0              2  86666.666667

# %% [markdown]
# Query 5E: In Query 5D limit the result to departments with fewer than 4 employees

# %%
df[df['NUM_EMPLOYEES'] < 4]
# Out:
#    NUM_EMPLOYEES    AVG_SALARY
# 0              2  86666.666667

# %% [markdown]
# BONUS Query 6: Similar to 4B but instead of department ID use department name. Retrieve a list of employees ordered by department name, and within each department ordered alphabetically in descending order by last name.

# %%
employees
# Out:
#   EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 0  E1001     John   Thomas  123456 1976-09-01   M
# 1  E1002    Alice    James  123457 1972-07-31   F
# 2  E1003    Steve    Wells  123458 1980-10-08   M
# 3  E1004  Santosh    Kumar  123459 1985-07-20   M
# 4  E1005    Ahmed  Hussain  123410 1981-04-01   M
# 5  E1006    Nancy    Allen  123411 1978-06-02   F
# 6  E1007     Mary   Thomas  123412 1975-05-05   F
# 7  E1008  Bharath    Gupta  123413 1985-06-05   M
# 8  E1009   Andrea    Jones  123414 1990-09-07   F
# 9  E1010      Ann    Jacob  123415 1982-03-30   F
#
#                         ADDRESS  JOB_ID  SALARY  MANAGER_ID  DEP_ID  \
# 0         5631 Rice, OakPark,IL     100  100000       30001       2
# 1        980 Berry ln, Elgin,IL     200   80000       30002       5
# 2          291 Springs, Gary,IL     300   50000       30002       5
# 3      511 Aurora Av, Aurora,IL     400   60000       30004       5
# 4       216 Oak Tree, Geneva,IL     500   70000       30001       2
# 5        111 Green Pl, Elgin,IL     600   90000       30001       2
# 6          100 Rose Pl, Gary,IL     650   65000       30003       7
# 7   145 Berry Ln, Naperville,IL     660   65000       30003       7
# 8       120 Fall Creek, Gary,IL     234   70000       30003       7
# 9  111 Britany Springs,Elgin,IL     220   70000       30004       5
#
#    YEAROFBIRTH
# 0         1976
# 1         1972
# 2         1980
# 3         1985
# 4         1981
# 5         1978
# 6         1975
# 7         1985
# 8         1990
# 9         1982

# %%
dept
# Out:
#    DEPT_ID         DEP_NAME  MANAGER_ID LOC_ID
# 0        2  Architect Group       30001  L0001
# 1        5   Software Group       30002  L0002
# 2        7      Design Team       30003  L0003
# 3        5   Software Group       30004  L0004

# %%
df2 = pd.merge(left=employees,right=dept,how='inner',left_on='DEP_ID', right_on='DEPT_ID')

# %%
df2
# Out:
#    EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 0   E1001     John   Thomas  123456 1976-09-01   M
# 1   E1005    Ahmed  Hussain  123410 1981-04-01   M
# 2   E1006    Nancy    Allen  123411 1978-06-02   F
# 3   E1002    Alice    James  123457 1972-07-31   F
# 4   E1002    Alice    James  123457 1972-07-31   F
# 5   E1003    Steve    Wells  123458 1980-10-08   M
# 6   E1003    Steve    Wells  123458 1980-10-08   M
# 7   E1004  Santosh    Kumar  123459 1985-07-20   M
# 8   E1004  Santosh    Kumar  123459 1985-07-20   M
# 9   E1010      Ann    Jacob  123415 1982-03-30   F
# 10  E1010      Ann    Jacob  123415 1982-03-30   F
# 11  E1007     Mary   Thomas  123412 1975-05-05   F
# 12  E1008  Bharath    Gupta  123413 1985-06-05   M
# 13  E1009   Andrea    Jones  123414 1990-09-07   F
#
#                          ADDRESS  JOB_ID  SALARY  MANAGER_ID_x  DEP_ID  \
# 0          5631 Rice, OakPark,IL     100  100000         30001       2
# 1        216 Oak Tree, Geneva,IL     500   70000         30001       2
# 2         111 Green Pl, Elgin,IL     600   90000         30001       2
# 3         980 Berry ln, Elgin,IL     200   80000         30002       5
# 4         980 Berry ln, Elgin,IL     200   80000         30002       5
# 5           291 Springs, Gary,IL     300   50000         30002       5
# 6           291 Springs, Gary,IL     300   50000         30002       5
# 7       511 Aurora Av, Aurora,IL     400   60000         30004       5
# 8       511 Aurora Av, Aurora,IL     400   60000         30004       5
# 9   111 Britany Springs,Elgin,IL     220   70000         30004       5
# 10  111 Britany Springs,Elgin,IL     220   70000         30004       5
# 11          100 Rose Pl, Gary,IL     650   65000         30003       7
# 12   145 Berry Ln, Naperville,IL     660   65000         30003       7
# 13       120 Fall Creek, Gary,IL     234   70000         30003       7
#
#     YEAROFBIRTH  DEPT_ID         DEP_NAME  MANAGER_ID_y LOC_ID
# 0          1976        2  Architect Group         30001  L0001
# 1          1981        2  Architect Group         30001  L0001
# 2          1978        2  Architect Group         30001  L0001
# 3          1972        5   Software Group         30002  L0002
# 4          1972        5   Software Group         30004  L0004
# 5          1980        5   Software Group         30002  L0002
# 6          1980        5   Software Group         30004  L0004
# 7          1985        5   Software Group         30002  L0002
# 8          1985        5   Software Group         30004  L0004
# 9          1982        5   Software Group         30002  L0002
# 10         1982        5   Software Group         30004  L0004
# 11         1975        7      Design Team         30003  L0003
# 12         1985        7      Design Team         30003  L0003
# 13         1990        7      Design Team         30003  L0003

# %%
df2.sort_values(by='DEP_NAME')
# Out:
#    EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 0   E1001     John   Thomas  123456 1976-09-01   M
# 1   E1005    Ahmed  Hussain  123410 1981-04-01   M
# 2   E1006    Nancy    Allen  123411 1978-06-02   F
# 11  E1007     Mary   Thomas  123412 1975-05-05   F
# 12  E1008  Bharath    Gupta  123413 1985-06-05   M
# 13  E1009   Andrea    Jones  123414 1990-09-07   F
# 3   E1002    Alice    James  123457 1972-07-31   F
# 4   E1002    Alice    James  123457 1972-07-31   F
# 5   E1003    Steve    Wells  123458 1980-10-08   M
# 6   E1003    Steve    Wells  123458 1980-10-08   M
# 7   E1004  Santosh    Kumar  123459 1985-07-20   M
# 8   E1004  Santosh    Kumar  123459 1985-07-20   M
# 9   E1010      Ann    Jacob  123415 1982-03-30   F
# 10  E1010      Ann    Jacob  123415 1982-03-30   F
#
#                          ADDRESS  JOB_ID  SALARY  MANAGER_ID_x  DEP_ID  \
# 0          5631 Rice, OakPark,IL     100  100000         30001       2
# 1        216 Oak Tree, Geneva,IL     500   70000         30001       2
# 2         111 Green Pl, Elgin,IL     600   90000         30001       2
# 11          100 Rose Pl, Gary,IL     650   65000         30003       7
# 12   145 Berry Ln, Naperville,IL     660   65000         30003       7
# 13       120 Fall Creek, Gary,IL     234   70000         30003       7
# 3         980 Berry ln, Elgin,IL     200   80000         30002       5
# 4         980 Berry ln, Elgin,IL     200   80000         30002       5
# 5           291 Springs, Gary,IL     300   50000         30002       5
# 6           291 Springs, Gary,IL     300   50000         30002       5
# 7       511 Aurora Av, Aurora,IL     400   60000         30004       5
# 8       511 Aurora Av, Aurora,IL     400   60000         30004       5
# 9   111 Britany Springs,Elgin,IL     220   70000         30004       5
# 10  111 Britany Springs,Elgin,IL     220   70000         30004       5
#
#     YEAROFBIRTH  DEPT_ID         DEP_NAME  MANAGER_ID_y LOC_ID
# 0          1976        2  Architect Group         30001  L0001
# 1          1981        2  Architect Group         30001  L0001
# 2          1978        2  Architect Group         30001  L0001
# 11         1975        7      Design Team         30003  L0003
# 12         1985        7      Design Team         30003  L0003
# 13         1990        7      Design Team         30003  L0003
# 3          1972        5   Software Group         30002  L0002
# 4          1972        5   Software Group         30004  L0004
# 5          1980        5   Software Group         30002  L0002
# 6          1980        5   Software Group         30004  L0004
# 7          1985        5   Software Group         30002  L0002
# 8          1985        5   Software Group         30004  L0004
# 9          1982        5   Software Group         30002  L0002
# 10         1982        5   Software Group         30004  L0004

# %%
df3 = df2.sort_values(by='DEP_NAME')

# %%
df3
# Out:
#    EMP_ID   F_NAME   L_NAME     SSN     B_DATE SEX  \
# 0   E1001     John   Thomas  123456 1976-09-01   M
# 1   E1005    Ahmed  Hussain  123410 1981-04-01   M
# 2   E1006    Nancy    Allen  123411 1978-06-02   F
# 11  E1007     Mary   Thomas  123412 1975-05-05   F
# 12  E1008  Bharath    Gupta  123413 1985-06-05   M
# 13  E1009   Andrea    Jones  123414 1990-09-07   F
# 3   E1002    Alice    James  123457 1972-07-31   F
# 4   E1002    Alice    James  123457 1972-07-31   F
# 5   E1003    Steve    Wells  123458 1980-10-08   M
# 6   E1003    Steve    Wells  123458 1980-10-08   M
# 7   E1004  Santosh    Kumar  123459 1985-07-20   M
# 8   E1004  Santosh    Kumar  123459 1985-07-20   M
# 9   E1010      Ann    Jacob  123415 1982-03-30   F
# 10  E1010      Ann    Jacob  123415 1982-03-30   F
#
#                          ADDRESS  JOB_ID  SALARY  MANAGER_ID_x  DEP_ID  \
# 0          5631 Rice, OakPark,IL     100  100000         30001       2
# 1        216 Oak Tree, Geneva,IL     500   70000         30001       2
# 2         111 Green Pl, Elgin,IL     600   90000         30001       2
# 11          100 Rose Pl, Gary,IL     650   65000         30003       7
# 12   145 Berry Ln, Naperville,IL     660   65000         30003       7
# 13       120 Fall Creek, Gary,IL     234   70000         30003       7
# 3         980 Berry ln, Elgin,IL     200   80000         30002       5
# 4         980 Berry ln, Elgin,IL     200   80000         30002       5
# 5           291 Springs, Gary,IL     300   50000         30002       5
# 6           291 Springs, Gary,IL     300   50000         30002       5
# 7       511 Aurora Av, Aurora,IL     400   60000         30004       5
# 8       511 Aurora Av, Aurora,IL     400   60000         30004       5
# 9   111 Britany Springs,Elgin,IL     220   70000         30004       5
# 10  111 Britany Springs,Elgin,IL     220   70000         30004       5
#
#     YEAROFBIRTH  DEPT_ID         DEP_NAME  MANAGER_ID_y LOC_ID
# 0          1976        2  Architect Group         30001  L0001
# 1          1981        2  Architect Group         30001  L0001
# 2          1978        2  Architect Group         30001  L0001
# 11         1975        7      Design Team         30003  L0003
# 12         1985        7      Design Team         30003  L0003
# 13         1990        7      Design Team         30003  L0003
# 3          1972        5   Software Group         30002  L0002
# 4          1972        5   Software Group         30004  L0004
# 5          1980        5   Software Group         30002  L0002
# 6          1980        5   Software Group         30004  L0004
# 7          1985        5   Software Group         30002  L0002
# 8          1985        5   Software Group         30004  L0004
# 9          1982        5   Software Group         30002  L0002
# 10         1982        5   Software Group         30004  L0004

# %%
df3.groupby('DEP_NAME', as_index=False)['L_NAME'].count()
# Out:
#           DEP_NAME  L_NAME
# 0  Architect Group       3
# 1      Design Team       3
# 2   Software Group       8
